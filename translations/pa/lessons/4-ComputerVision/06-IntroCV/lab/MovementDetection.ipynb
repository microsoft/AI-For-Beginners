# %% [markdown]
# **ਤੁਹਾਡਾ ਲਕਸ਼ਯ** ਹੋਵੇਗਾ Optical Flow ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਇਹ ਨਿਰਧਾਰਤ ਕਰਨਾ ਕਿ ਵੀਡੀਓ ਦੇ ਕਿਹੜੇ ਹਿੱਸੇ ਉੱਪਰ/ਹੇਠਾਂ/ਖੱਬੇ/ਸੱਜੇ ਦੀਆਂ ਹਰਕਤਾਂ ਦਰਸਾਉਂਦੇ ਹਨ।
#
# ਲੈਕਚਰ ਵਿੱਚ ਵਰਣਨ ਕੀਤੇ ਤਰੀਕੇ ਅਨੁਸਾਰ ਵੀਡੀਓ ਫ੍ਰੇਮ ਪ੍ਰਾਪਤ ਕਰਨਾ ਸ਼ੁਰੂ ਕਰੋ:

# %%
# Code here

# %% [markdown]
# ਹੁਣ, ਲੈਕਚਰ ਵਿੱਚ ਵਰਣਨ ਕੀਤੇ ਅਨੁਸਾਰ ਘਣਤਰੀਕ آپਟੀਕਲ ਫਲੋ ਫ੍ਰੇਮ ਦੀ ਗਣਨਾ ਕਰੋ, ਅਤੇ ਘਣਤਰੀਕ آپਟੀਕਲ ਫਲੋ ਨੂੰ ਧ੍ਰੁਵਿਕ ਨਿਰਦੇਸ਼ਾਂ ਵਿੱਚ ਪਰਿਵਰਤਿਤ ਕਰੋ:

# %%
# Code here

# %% [markdown]
# ਹਰ ਆਪਟੀਕਲ ਫਲੋ ਫਰੇਮ ਲਈ ਦਿਸ਼ਾਵਾਂ ਦਾ ਹਿਸਟੋਗ੍ਰਾਮ ਬਣਾਓ। ਹਿਸਟੋਗ੍ਰਾਮ ਦਿਖਾਉਂਦਾ ਹੈ ਕਿ ਕਿੰਨੇ ਵੈਕਟਰ ਕੁਝ ਨਿਰਧਾਰਿਤ ਬਿਨਾਂ ਵਿੱਚ ਆਉਂਦੇ ਹਨ, ਅਤੇ ਇਹ ਫਰੇਮ 'ਤੇ ਹਲਚਲ ਦੀਆਂ ਵੱਖ-ਵੱਖ ਦਿਸ਼ਾਵਾਂ ਨੂੰ ਵੱਖ ਕਰਨਾ ਚਾਹੀਦਾ ਹੈ।
#
# > ਤੁਸੀਂ ਉਹਨਾਂ ਸਾਰੇ ਵੈਕਟਰਾਂ ਨੂੰ ਜ਼ੀਰੋ ਕਰਨਾ ਚਾਹੋਗੇ ਜਿਨ੍ਹਾਂ ਦੀ ਮੈਗਨੀਟਿਊਡ ਕੁਝ ਨਿਰਧਾਰਿਤ ਸੀਮਾ ਤੋਂ ਹੇਠਾਂ ਹੈ। ਇਹ ਵੀਡੀਓ ਵਿੱਚ ਛੋਟੀਆਂ ਅਤਿਰਿਕਤ ਹਲਚਲਾਂ, ਜਿਵੇਂ ਕਿ ਅੱਖਾਂ ਅਤੇ ਸਿਰ, ਨੂੰ ਹਟਾ ਦੇਵੇਗਾ।
#
# ਕੁਝ ਫਰੇਮਾਂ ਲਈ ਹਿਸਟੋਗ੍ਰਾਮ ਪਲਾਟ ਕਰੋ।

# %%
# Code here

# %% [markdown]
# ਹਿਸਟੋਗ੍ਰਾਮਾਂ ਨੂੰ ਵੇਖਦੇ ਹੋਏ, ਇਹ ਸਿੱਧਾ ਸਾਫ਼ ਹੋਣਾ ਚਾਹੀਦਾ ਹੈ ਕਿ ਗਤੀ ਦੀ ਦਿਸ਼ਾ ਕਿਵੇਂ ਨਿਰਧਾਰਤ ਕਰਨੀ ਹੈ। ਤੁਹਾਨੂੰ ਉਹ ਬਿਨ ਚੁਣਨ ਦੀ ਲੋੜ ਹੈ ਜੋ ਉੱਪਰ/ਹੇਠਾਂ/ਖੱਬੇ/ਸੱਜੇ ਦਿਸ਼ਾਵਾਂ ਨਾਲ ਸਬੰਧਤ ਹਨ, ਅਤੇ ਜੋ ਇੱਕ ਨਿਰਧਾਰਤ ਸੀਮਾ ਤੋਂ ਉੱਪਰ ਹਨ।

# %%
# Code here

# %% [markdown]
# ਵਧਾਈਆਂ! ਜੇਕਰ ਤੁਸੀਂ ਉੱਪਰ ਦਿੱਤੇ ਸਾਰੇ ਕਦਮ ਪੂਰੇ ਕਰ ਲਏ ਹਨ, ਤਾਂ ਤੁਸੀਂ ਲੈਬ ਪੂਰੀ ਕਰ ਲਈ ਹੈ!

# %% [markdown]
# ---
#
# **ਅਸਵੀਕਰਤੀ**:
# ਇਹ ਦਸਤਾਵੇਜ਼ AI ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਅਨੁਵਾਦ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀ ਹੋਣ ਦਾ ਯਤਨ ਕਰਦੇ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਦਿਓ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸੁੱਤੀਆਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਇਸ ਦੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਲਿਖਿਆ ਦਸਤਾਵੇਜ਼ ਪ੍ਰਮਾਣਿਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਮਹੱਤਵਪੂਰਨ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਇਸ ਅਨੁਵਾਦ ਦੇ ਪ੍ਰਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੇ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆ ਲਈ ਅਸੀਂ ਜ਼ਿੰਮੇਵਾਰ ਨਹੀਂ ਹਾਂ।
