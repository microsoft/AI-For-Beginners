# %% [markdown]
# ## Определение движения ладони с использованием оптического потока
#
# Эта лабораторная работа является частью [курса "Искусственный интеллект для начинающих"](http://aka.ms/ai-beginners).
#
# Рассмотрим [это видео](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4), где ладонь человека движется влево/вправо/вверх/вниз на стабильном фоне.
#
# **Ваша цель** — использовать оптический поток, чтобы определить, какие части видео содержат движения вверх/вниз/влево/вправо.
#
# Начните с получения кадров из видео, как описано в лекции:

# %%
# Code here

# %% [markdown]
# Теперь рассчитайте плотные оптические потоки кадров, как описано в лекции, и преобразуйте плотные оптические потоки в полярные координаты:

# %%
# Code here

# %% [markdown]
# Постройте гистограмму направлений для каждого кадра оптического потока. Гистограмма показывает, сколько векторов попадает в определённый диапазон, и должна разделять различные направления движения на кадре.
#
# > Возможно, вы захотите обнулить все векторы, величина которых ниже определённого порога. Это поможет избавиться от небольших лишних движений в видео, таких как движения глаз и головы.
#
# Постройте гистограммы для некоторых кадров.

# %%
# Code here

# %% [markdown]
# Рассматривая гистограммы, должно быть довольно просто определить направление движения. Вам нужно выбрать те столбцы, которые соответствуют направлениям вверх/вниз/влево/вправо и которые превышают определенный порог.

# %%
# Code here

# %% [markdown]
# Поздравляем! Если вы выполнили все шаги выше, вы завершили лабораторную работу!

# %% [markdown]
# ---
#
# **Отказ от ответственности**:
# Этот документ был переведен с помощью сервиса автоматического перевода [Co-op Translator](https://github.com/Azure/co-op-translator). Хотя мы стремимся к точности, пожалуйста, учитывайте, что автоматические переводы могут содержать ошибки или неточности. Оригинальный документ на его исходном языке следует считать авторитетным источником. Для получения критически важной информации рекомендуется профессиональный перевод человеком. Мы не несем ответственности за любые недоразумения или неправильные интерпретации, возникающие в результате использования данного перевода.
