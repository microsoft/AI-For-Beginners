# %% [markdown]
# ## Детекција покрета длана коришћењем оптичког тока
#
# Овај практични рад је део [курикулума за почетнике у вештачкој интелигенцији](http://aka.ms/ai-beginners).
#
# Погледајте [овај видео](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4), у коме се длан особе помера лево/десно/горе/доле на стабилној позадини.
#
# **Ваш циљ** биће да користите оптички ток како бисте утврдили који делови видеа садрже покрете горе/доле/лево/десно.
#
# Почните са добијањем кадрова из видеа, како је описано у предавању:

# %%
# Code here

# %% [markdown]
# Сада израчунајте густе оптичке токове кадрова како је описано на предавању, и конвертујте густе оптичке токове у поларне координате:

# %%
# Code here

# %% [markdown]
# Направите хистограм праваца за сваки кадар оптичког тока. Хистограм показује колико вектора спада у одређени опсег, и треба да раздвоји различите правце кретања на кадру.
#
# > Можда ћете желети да занемарите све векторе чија је величина испод одређеног прага. Ово ће уклонити мале, непотребне покрете у видеу, као што су покрети очију и главе.
#
# Прикажите хистограме за неке од кадрова.

# %%
# Code here

# %% [markdown]
# Гледајући хистограме, требало би да буде прилично једноставно како одредити правац кретања. Потребно је одабрати оне колоне које одговарају правцима горе/доле/лево/десно, и које су изнад одређеног прага.

# %%
# Code here

# %% [markdown]
# Честитамо! Ако сте урадили све кораке изнад, завршили сте лабораторију!

# %% [markdown]
# ---
#
# **Одрицање од одговорности**:
# Овај документ је преведен коришћењем услуге за превођење помоћу вештачке интелигенције [Co-op Translator](https://github.com/Azure/co-op-translator). Иако се трудимо да обезбедимо тачност, молимо вас да имате у виду да аутоматизовани преводи могу садржати грешке или нетачности. Оригинални документ на његовом изворном језику треба сматрати ауторитативним извором. За критичне информације препоручује се професионални превод од стране људи. Не преузимамо одговорност за било каква погрешна тумачења или неспоразуме који могу настати услед коришћења овог превода.
