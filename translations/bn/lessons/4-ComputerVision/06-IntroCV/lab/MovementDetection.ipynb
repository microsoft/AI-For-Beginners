# %% [markdown]
# ## অপটিক্যাল ফ্লো ব্যবহার করে হাতের নড়াচড়া শনাক্তকরণ
#
# এই ল্যাবটি [AI for Beginners Curriculum](http://aka.ms/ai-beginners)-এর অংশ।
#
# [এই ভিডিওটি](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4) বিবেচনা করুন, যেখানে একটি ব্যক্তির হাত স্থির পটভূমির উপর বাম/ডান/উপর/নিচে নড়াচড়া করছে।
#
# **আপনার লক্ষ্য** হবে অপটিক্যাল ফ্লো ব্যবহার করে নির্ধারণ করা, ভিডিওর কোন অংশে উপর/নিচ/বাম/ডান নড়াচড়া রয়েছে।
#
# লেকচারে বর্ণিত পদ্ধতি অনুসারে ভিডিও ফ্রেম সংগ্রহ করা দিয়ে শুরু করুন:

# %%
# Code here

# %% [markdown]
# এখন, লেকচারে বর্ণিত অনুযায়ী ঘন অপটিক্যাল ফ্লো ফ্রেমগুলি গণনা করুন এবং ঘন অপটিক্যাল ফ্লোকে পোলার কোঅর্ডিনেটে রূপান্তর করুন:

# %%
# Code here

# %% [markdown]
# প্রতিটি অপটিক্যাল ফ্লো ফ্রেমের জন্য দিকনির্দেশের একটি হিস্টোগ্রাম তৈরি করুন। একটি হিস্টোগ্রাম দেখায় কতগুলো ভেক্টর নির্দিষ্ট বিনের মধ্যে পড়ে, এবং এটি ফ্রেমে বিভিন্ন দিকের গতিবিধিকে আলাদা করে।
#
# > আপনি এমন সমস্ত ভেক্টরকে শূন্য করতে চাইতে পারেন যাদের মাত্রা নির্দিষ্ট সীমার নিচে। এটি ভিডিওতে ছোট অতিরিক্ত গতিবিধি, যেমন চোখ এবং মাথার নড়াচড়া, দূর করতে সাহায্য করবে।
#
# কিছু ফ্রেমের জন্য হিস্টোগ্রামগুলো প্লট করুন।

# %%
# Code here

# %% [markdown]
# হিস্টোগ্রামগুলোর দিকে তাকালে, গতির দিক নির্ধারণ করা বেশ সহজ হওয়া উচিত। আপনাকে সেই বিনগুলো নির্বাচন করতে হবে যা উপরে/নিচে/বামে/ডানে দিকের সাথে সম্পর্কিত, এবং যা নির্দিষ্ট সীমার উপরে রয়েছে।

# %%
# Code here

# %% [markdown]
# অভিনন্দন! যদি আপনি উপরের সমস্ত ধাপ সম্পন্ন করে থাকেন, তবে আপনি ল্যাবটি সম্পন্ন করেছেন!

# %% [markdown]
# ---
#
# **অস্বীকৃতি**:
# এই নথিটি AI অনুবাদ পরিষেবা [Co-op Translator](https://github.com/Azure/co-op-translator) ব্যবহার করে অনুবাদ করা হয়েছে। আমরা যথাসাধ্য সঠিকতা নিশ্চিত করার চেষ্টা করি, তবে অনুগ্রহ করে মনে রাখবেন যে স্বয়ংক্রিয় অনুবাদে ত্রুটি বা অসঙ্গতি থাকতে পারে। মূল ভাষায় থাকা নথিটিকে প্রামাণিক উৎস হিসেবে বিবেচনা করা উচিত। গুরুত্বপূর্ণ তথ্যের জন্য, পেশাদার মানব অনুবাদ সুপারিশ করা হয়। এই অনুবাদ ব্যবহারের ফলে কোনো ভুল বোঝাবুঝি বা ভুল ব্যাখ্যা হলে আমরা দায়বদ্ধ থাকব না।
