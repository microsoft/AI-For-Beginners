# %% [markdown]
# ## လက်ဖဝါးလှုပ်ရှားမှုကို Optical Flow အသုံးပြု၍ ရှာဖွေခြင်း
#
# ဤလက်တွေ့လေ့ကျင့်ခန်းသည် [AI for Beginners Curriculum](http://aka.ms/ai-beginners) ၏ အစိတ်အပိုင်းတစ်ခုဖြစ်သည်။
#
# [ဤဗီဒီယို](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4) ကိုစဉ်းစားပါ၊ ဗီဒီယိုတွင် လူတစ်ဦး၏ လက်ဖဝါးသည် တည်ငြိမ်သောနောက်ခံပေါ်တွင် ဘယ်/ညာ/အပေါ်/အောက်သို့ လှုပ်ရှားနေသည်။
#
# **သင့်ရည်မှန်းချက်**မှာ Optical Flow ကိုအသုံးပြုပြီး ဗီဒီယို၏ ဘယ်အပိုင်းများတွင် အပေါ်/အောက်/ဘယ်/ညာ လှုပ်ရှားမှုများပါဝင်သည်ကို သတ်မှတ်ရန်ဖြစ်သည်။
#
# စာတန်းထဲတွင် ဖော်ပြထားသည့်အတိုင်း ဗီဒီယိုဖရိမ်များကို ရယူခြင်းဖြင့် စတင်ပါ:

# %%
# Code here

# %% [markdown]
# အခုတော့၊ သင်ခန်းစာတွင် ဖော်ပြထားသည့်အတိုင်း အထူအလင်းမှုတ်စီးရေကို ရှုထောင်များတွက်ချက်ပြီး၊ အထူအလင်းမှုတ်စီးရေကို ပိုလာကိုဩဒိနိတ်များသို့ ပြောင်းပါ။

# %%
# Code here

# %% [markdown]
# အော့ပတီကယ် ဖလို ဖရိမ်းတစ်ခုစီအတွက် လမ်းညွှန်မှုများ၏ ဟစ်စတိုဂရမ်ကို တည်ဆောက်ပါ။ ဟစ်စတိုဂရမ်သည် ဘယ်လောက်အရေအတွက်ရှိသော ဗက်တာများက သတ်မှတ်ထားသော ဘင်တစ်ခုအောက်တွင် ကျရောက်နေသည်ကို ပြသပြီး၊ ဖရိမ်းပေါ်တွင် လှုပ်ရှားမှု၏ လမ်းညွှန်မှုများကို ခွဲခြားပြသနိုင်ရမည်ဖြစ်သည်။
#
# > သတ်မှတ်ထားသော စံနှုန်းအောက်ရှိ မက်ဂနီကျုဒ်များကို သုညအဖြစ် သတ်မှတ်လိုက်ရန်လိုအပ်နိုင်ပါသည်။ ဤနည်းလမ်းဖြင့် ဗီဒီယိုတွင် မျက်လုံးနှင့် ခေါင်းကဲ့သို့သော သေးငယ်သော အပိုလှုပ်ရှားမှုများကို ဖယ်ရှားနိုင်မည်ဖြစ်သည်။
#
# ဖရိမ်းအချို့အတွက် ဟစ်စတိုဂရမ်များကို ပုံဖော်ပြပါ။

# %%
# Code here

# %% [markdown]
# ဟစ်စတိုဂရမ်များကိုကြည့်ပါက၊ လှုပ်ရှားမှုဦးတည်ရာကိုသတ်မှတ်ရန် အလွန်ရိုးရှင်းသင့်သည်။ အပေါ်/အောက်/ဘယ်/ညာဦးတည်ရာများနှင့်ကိုက်ညီသော bin များကိုရွေးချယ်ရန်လိုအပ်ပြီး၊ အချို့သော threshold အထက်ရှိသော bin များကိုသာရွေးချယ်ပါ။

# %%
# Code here

# %% [markdown]
# အောင်မြင်ပါတယ်! အထက်ပါအဆင့်များအားလုံးကို ပြုလုပ်ပြီးပါက၊ သင်သည် လက်တွေ့လေ့လာခန်းကို ပြီးမြောက်ခဲ့ပါပြီ!

# %% [markdown]
# ---
#
# **အကြောင်းကြားချက်**:
# ဤစာရွက်စာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) ကို အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှုအတွက် ကြိုးစားနေသော်လည်း၊ အလိုအလျောက် ဘာသာပြန်မှုများတွင် အမှားများ သို့မဟုတ် မတိကျမှုများ ပါဝင်နိုင်သည်ကို သတိပြုပါ။ မူရင်းစာရွက်စာတမ်းကို ၎င်း၏ မူရင်းဘာသာစကားဖြင့် အာဏာတရားရှိသော အရင်းအမြစ်အဖြစ် ရှုလေ့ရှိသင့်ပါသည်။ အရေးကြီးသော အချက်အလက်များအတွက် လူက ဘာသာပြန်မှုကို အသုံးပြုရန် အကြံပြုပါသည်။ ဤဘာသာပြန်မှုကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော အလွဲအလွတ်များ သို့မဟုတ် အနားယူမှုများအတွက် ကျွန်ုပ်တို့သည် တာဝန်မယူပါ။
