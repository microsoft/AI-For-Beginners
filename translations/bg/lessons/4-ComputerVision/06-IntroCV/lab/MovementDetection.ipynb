# %% [markdown]
# ## Откриване на движение на дланта с помощта на оптичен поток
#
# Тази лабораторна работа е част от [Учебната програма за начинаещи в ИИ](http://aka.ms/ai-beginners).
#
# Разгледайте [това видео](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4), в което дланта на човек се движи наляво/надясно/нагоре/надолу на стабилен фон.
#
# **Вашата цел** е да използвате оптичен поток, за да определите кои части от видеото съдържат движения нагоре/надолу/наляво/надясно.
#
# Започнете с извличане на кадри от видеото, както е описано в лекцията:

# %%
# Code here

# %% [markdown]
# Сега изчислете кадрите на плътния оптичен поток, както е описано в лекцията, и преобразувайте плътния оптичен поток в полярни координати:

# %%
# Code here

# %% [markdown]
# Създайте хистограма на посоките за всяка рамка на оптичния поток. Хистограмата показва колко вектори попадат в определен интервал и трябва да разделя различните посоки на движение в рамката.
#
# > Може също да искате да занулите всички вектори, чиято големина е под определен праг. Това ще премахне малки допълнителни движения във видеото, като например движения на очите и главата.
#
# Начертайте хистограмите за някои от рамките.

# %%
# Code here

# %% [markdown]
# Гледайки хистограмите, трябва да е доста лесно да се определи посоката на движение. Трябва да изберете тези колони, които съответстват на посоките нагоре/надолу/наляво/надясно и които са над определен праг.

# %%
# Code here

# %% [markdown]
# Поздравления! Ако сте изпълнили всички горепосочени стъпки, сте завършили лабораторията!

# %% [markdown]
# ---
#
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI услуга за превод [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля, имайте предвид, че автоматизираните преводи може да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за недоразумения или погрешни интерпретации, произтичащи от използването на този превод.
