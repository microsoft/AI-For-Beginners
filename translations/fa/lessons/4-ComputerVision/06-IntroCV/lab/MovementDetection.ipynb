# %% [markdown]
# ## تشخیص حرکت کف دست با استفاده از Optical Flow
#
# این آزمایش بخشی از [برنامه درسی AI برای مبتدیان](http://aka.ms/ai-beginners) است.
#
# [این ویدیو](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4) را در نظر بگیرید، که در آن کف دست یک فرد روی یک پس‌زمینه ثابت به سمت چپ/راست/بالا/پایین حرکت می‌کند.
#
# **هدف شما** این است که با استفاده از Optical Flow تعیین کنید کدام بخش‌های ویدیو شامل حرکات بالا/پایین/چپ/راست هستند.
#
# ابتدا با دریافت فریم‌های ویدیو همان‌طور که در درس توضیح داده شد، شروع کنید:

# %%
# Code here

# %% [markdown]
# اکنون، فریم‌های جریان نوری متراکم را همان‌طور که در درس توضیح داده شد محاسبه کنید و جریان نوری متراکم را به مختصات قطبی تبدیل کنید:

# %%
# Code here

# %% [markdown]
# ساخت هیستوگرام جهت‌ها برای هر فریم جریان نوری. یک هیستوگرام نشان می‌دهد که چند بردار در هر بازه خاص قرار می‌گیرند و باید جهت‌های مختلف حرکت در فریم را از هم جدا کند.
#
# > ممکن است بخواهید تمام بردارهایی را که اندازه آن‌ها کمتر از یک آستانه مشخص است صفر کنید. این کار حرکات کوچک اضافی در ویدیو، مانند حرکات چشم و سر، را حذف می‌کند.
#
# هیستوگرام‌ها را برای برخی از فریم‌ها رسم کنید.

# %%
# Code here

# %% [markdown]
# نگاه کردن به هیستوگرام‌ها باید کاملاً واضح باشد که چگونه جهت حرکت را تعیین کنید. شما باید آن دسته از ستون‌هایی را انتخاب کنید که با جهت‌های بالا/پایین/چپ/راست مطابقت دارند و بالاتر از یک آستانه خاص هستند.

# %%
# Code here

# %% [markdown]
# تبریک! اگر تمام مراحل بالا را انجام داده‌اید، آزمایشگاه را به پایان رسانده‌اید!

# %% [markdown]
# ---
#
# **سلب مسئولیت**:
# این سند با استفاده از سرویس ترجمه هوش مصنوعی [Co-op Translator](https://github.com/Azure/co-op-translator) ترجمه شده است. در حالی که ما تلاش می‌کنیم دقت را حفظ کنیم، لطفاً توجه داشته باشید که ترجمه‌های خودکار ممکن است شامل خطاها یا نادرستی‌ها باشند. سند اصلی به زبان اصلی آن باید به عنوان منبع معتبر در نظر گرفته شود. برای اطلاعات حساس، توصیه می‌شود از ترجمه حرفه‌ای انسانی استفاده کنید. ما مسئولیتی در قبال سوء تفاهم‌ها یا تفسیرهای نادرست ناشی از استفاده از این ترجمه نداریم.
