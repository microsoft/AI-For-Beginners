# %% [markdown]
# ## Optical Flow மூலம் கையடக்க இயக்கத்தை கண்டறிதல்
#
# இந்த பயிற்சி [AI for Beginners Curriculum](http://aka.ms/ai-beginners) இன் ஒரு பகுதியாகும்.
#
# [இந்த வீடியோவை](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4) கவனியுங்கள், இதில் ஒரு நபரின் கையடக்கம் நிலையான பின்னணியில் இடது/வலது/மேலே/கீழே நகர்கிறது.
#
# <img src="../../../../../../translated_images/ta/palm-movement.341495f0e9c47da3.webp" width="30%" alt="கையடக்க இயக்கத்தின் ஃப்ரேம்"/>
#
# **உங்கள் இலக்கு** Optical Flow ஐ பயன்படுத்தி, வீடியோவில் எந்த பகுதிகள் மேலே/கீழே/இடது/வலது இயக்கங்களை கொண்டுள்ளன என்பதை கண்டறிவதாக இருக்கும்.
#
# வகுப்பில் விவரிக்கப்பட்டது போல வீடியோ ஃப்ரேம்களை பெறுவதில் தொடங்குங்கள்:

# %%
# Code here

# %% [markdown]
# இப்போது, சொற்பொழிவில் விவரிக்கப்பட்டுள்ளபடி அடர்த்தியான ஆப்டிகல் ப்ரோ ப்ரேம்களை கணக்கிடுங்கள், மற்றும் அடர்த்தியான ஆப்டிகல் ப்ரோவை துருவக் கோணங்களுக்கு மாற்றுங்கள்:

# %%
# Code here

# %% [markdown]
# ஒவ்வொரு optical flow ஃப்ரேமிற்கும் திசைகளின் ஹிஸ்டோகிராம் உருவாக்கவும். ஹிஸ்டோகிராம் என்பது குறிப்பிட்ட பின்களில் எத்தனை வெக்டர்கள் உள்ளன என்பதை காட்டும், மேலும் ஃப்ரேமில் உள்ள இயக்கத்தின் வெவ்வேறு திசைகளை பிரிக்க வேண்டும்.
#
# > நீங்கள் குறிப்பிட்ட அளவுக்கு குறைவான மாபெருமையை கொண்ட அனைத்து வெக்டர்களையும் μηலமாக்க விரும்பலாம். இது வீடியோவில் கண்கள் மற்றும் தலை போன்ற சிறிய கூடுதல் இயக்கங்களை நீக்க உதவும்.
#
# சில ஃப்ரேம்களுக்கான ஹிஸ்டோகிராம்களை வரைபடமாக காட்டவும்.

# %%
# Code here

# %% [markdown]
# ஹிஸ்டோகிராம்களைப் பார்க்கும்போது, இயக்கத்தின் திசையை நிர்ணயிப்பது மிகவும் எளிதாக இருக்க வேண்டும். மேலே/கீழே/இடம்/வலது திசைகளுக்கு ஏற்ப பொருந்தும் பின்களைத் தேர்ந்தெடுக்க வேண்டும், மேலும் அவை குறிப்பிட்ட ஒரு வரம்புக்கு மேல் இருக்க வேண்டும்.

# %%
# Code here

# %% [markdown]
# வாழ்த்துக்கள்! மேலே உள்ள அனைத்து படிகளையும் நீங்கள் முடித்திருந்தால், நீங்கள் ஆய்வகத்தை முடித்துவிட்டீர்கள்!

# %% [markdown]
# ---
#
# **குறிப்பு**:
# இந்த ஆவணம் [Co-op Translator](https://github.com/Azure/co-op-translator) என்ற AI மொழிபெயர்ப்பு சேவையைப் பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சிக்கின்றோம், ஆனால் தானியங்கி மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறான தகவல்கள் இருக்கக்கூடும் என்பதை தயவுசெய்து கவனத்தில் கொள்ளுங்கள். அதன் தாய்மொழியில் உள்ள மூல ஆவணம் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்முறை மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கங்களுக்கு நாங்கள் பொறுப்பல்ல.
