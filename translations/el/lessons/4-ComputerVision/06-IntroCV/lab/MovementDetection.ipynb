# %% [markdown]
# ## Ανίχνευση Κίνησης Παλάμης με Χρήση Οπτικής Ροής
#
# Αυτό το εργαστήριο αποτελεί μέρος του [Προγράμματος Σπουδών AI για Αρχάριους](http://aka.ms/ai-beginners).
#
# Σκεφτείτε [αυτό το βίντεο](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4), στο οποίο η παλάμη ενός ατόμου κινείται αριστερά/δεξιά/πάνω/κάτω σε ένα σταθερό φόντο.
#
# **Ο στόχος σας** είναι να χρησιμοποιήσετε την Οπτική Ροή για να προσδιορίσετε ποια μέρη του βίντεο περιέχουν κινήσεις προς τα πάνω/κάτω/αριστερά/δεξιά.
#
# Ξεκινήστε παίρνοντας τα καρέ του βίντεο όπως περιγράφεται στη διάλεξη:

# %%
# Code here

# %% [markdown]
# Τώρα, υπολογίστε τα καρέ πυκνής οπτικής ροής όπως περιγράφεται στη διάλεξη και μετατρέψτε την πυκνή οπτική ροή σε πολικές συντεταγμένες:

# %%
# Code here

# %% [markdown]
# Δημιουργήστε ένα ιστόγραμμα κατευθύνσεων για κάθε καρέ της οπτικής ροής. Ένα ιστόγραμμα δείχνει πόσοι διανύσματα ανήκουν σε συγκεκριμένα διαστήματα (bins) και θα πρέπει να διαχωρίζει τις διαφορετικές κατευθύνσεις κίνησης στο καρέ.
#
# > Μπορεί επίσης να θέλετε να μηδενίσετε όλα τα διανύσματα των οποίων το μέτρο είναι κάτω από ένα συγκεκριμένο όριο. Αυτό θα εξαλείψει μικρές επιπλέον κινήσεις στο βίντεο, όπως τα μάτια και το κεφάλι.
#
# Σχεδιάστε τα ιστογράμματα για μερικά από τα καρέ.

# %%
# Code here

# %% [markdown]
# Κοιτάζοντας τα ιστόγραμμα, θα πρέπει να είναι αρκετά απλό να προσδιορίσετε την κατεύθυνση της κίνησης. Πρέπει να επιλέξετε εκείνα τα διαστήματα που αντιστοιχούν στις κατευθύνσεις πάνω/κάτω/αριστερά/δεξιά και που είναι πάνω από ένα συγκεκριμένο όριο.

# %%
# Code here

# %% [markdown]
# Συγχαρητήρια! Εάν έχετε ολοκληρώσει όλα τα παραπάνω βήματα, έχετε ολοκληρώσει το εργαστήριο!

# %% [markdown]
# ---
#
# **Αποποίηση ευθύνης**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία αυτόματης μετάφρασης AI [Co-op Translator](https://github.com/Azure/co-op-translator). Παρόλο που καταβάλλουμε προσπάθειες για ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτόματες μεταφράσεις ενδέχεται να περιέχουν σφάλματα ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα θα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή εσφαλμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
