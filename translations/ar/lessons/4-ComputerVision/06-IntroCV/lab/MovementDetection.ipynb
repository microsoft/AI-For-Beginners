# %% [markdown]
# ## اكتشاف حركة الكف باستخدام التدفق البصري
#
# هذا المختبر هو جزء من [منهج الذكاء الاصطناعي للمبتدئين](http://aka.ms/ai-beginners).
#
# تأمل [هذا الفيديو](../../../../../../lessons/4-ComputerVision/06-IntroCV/lab/palm-movement.mp4)، حيث تتحرك كف الشخص إلى اليسار/اليمين/الأعلى/الأسفل على خلفية ثابتة.
#
# **هدفك** هو استخدام التدفق البصري لتحديد أي أجزاء من الفيديو تحتوي على حركات للأعلى/للأسفل/لليسار/لليمين.
#
# ابدأ بالحصول على إطارات الفيديو كما هو موضح في المحاضرة:

# %%
# Code here

# %% [markdown]
# الآن، احسب إطارات التدفق البصري الكثيف كما هو موضح في المحاضرة، وحوّل التدفق البصري الكثيف إلى إحداثيات قطبية:

# %%
# Code here

# %% [markdown]
# قم ببناء مخطط تكراري للاتجاهات لكل إطار من إطارات التدفق البصري. يُظهر المخطط التكراري عدد المتجهات التي تقع ضمن فئة معينة، ويجب أن يميز بين الاتجاهات المختلفة للحركة في الإطار.
#
# > قد ترغب أيضًا في تصفير جميع المتجهات التي يكون مقدارها أقل من عتبة معينة. سيساعد ذلك في التخلص من الحركات الصغيرة الإضافية في الفيديو، مثل حركات العين والرأس.
#
# قم برسم المخططات التكرارية لبعض الإطارات.

# %%
# Code here

# %% [markdown]
# عند النظر إلى المدرجات التكرارية، يجب أن يكون من السهل جدًا تحديد اتجاه الحركة. تحتاج إلى اختيار تلك الأشرطة التي تتوافق مع اتجاهات الأعلى/الأسفل/اليسار/اليمين، والتي تكون أعلى من حد معين.

# %%
# Code here

# %% [markdown]
# تهانينا! إذا كنت قد أكملت جميع الخطوات أعلاه، فقد أنهيت المختبر!

# %% [markdown]
# ---
#
# **إخلاء المسؤولية**:
# تمت ترجمة هذا المستند باستخدام خدمة الترجمة بالذكاء الاصطناعي [Co-op Translator](https://github.com/Azure/co-op-translator). بينما نسعى لتحقيق الدقة، يرجى العلم أن الترجمات الآلية قد تحتوي على أخطاء أو معلومات غير دقيقة. يجب اعتبار المستند الأصلي بلغته الأصلية المصدر الموثوق. للحصول على معلومات حساسة أو هامة، يُوصى بالاستعانة بترجمة بشرية احترافية. نحن غير مسؤولين عن أي سوء فهم أو تفسيرات خاطئة تنشأ عن استخدام هذه الترجمة.
